# %% [markdown]
# # Part 7

# %%
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates

plt.style.use('seaborn-v0_8-whitegrid')

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot_date(dates,y,linestyle='solid')

plt.gcf().autofmt_xdate()

plt.show()

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

plt.plot_date(dates,y,linestyle='solid')

plt.gcf().autofmt_xdate()

date_format = mpl_dates.DateFormatter('%b, %d, %Y')

plt.gca().xaxis.set_major_formatter(date_format)

plt.show()

# %%
data = pd.read_csv('data7.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date',inplace=True)

price_date = data['Date']
closing_price = data['Close']

plt.plot_date(price_date, closing_price, linestyle='solid')

date_format = mpl_dates.DateFormatter('%b, %d,%Y')
plt.gca().xaxis.set_major_formatter(date_format)

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Closing Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
plt.show()

# %%
data = pd.read_csv('data7.csv')
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)

date = data['Date']
opening_price = data['Open']

plt.plot_date(date, opening_price, linestyle='solid')

plt.gcf().autofmt_xdate()

date_formatter = mpl_dates.DateFormatter('%b, %d, %Y')
plt.gca().xaxis.set_major_formatter(date_formatter)

plt.title('Bitcoin Opening Prices')
plt.xlabel('Date')
plt.ylabel('Opening Prices')

plt.show()
